# %% [raw]
# assignment:
#
#     1. Take car crashes data set
#     2. load the data set
#     3. perform all the data visualization steps
#
#     bar, scatter, joint

# %% [raw]
# Steps:
#     1. import the necessary libraries
#     2. import the data sets
#     3. handling null values
#     4. outlier detection
#     5. dependent and independent variable seperation
#     6. Encode the categorical columns
#     7. split data between training set and testing set
#     8. feature scaling

# %% [markdown]
# # 1. import the necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 2. import the dataset

# %%
# csv , tsv  , json , excel

dataset=pd.read_csv("Churn_modelling.csv")

# put (r"locatin") to extract from somewhere else

# %%
dataset
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
dataset.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
dataset.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# ...

# %%
dataset.shape
# Out:
# (10000, 14)

# %%
dataset.info
# Out:
# <bound method DataFrame.info of       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
dataset.describe
# Out:
# <bound method NDFrame.describe of       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
# ...

# %%
dataset.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
dataset.corr()
# Out:
# C:\Users\sikha\AppData\Local\Temp\ipykernel_13300\2191645083.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataset.corr()
#                  RowNumber  CustomerId  CreditScore       Age    Tenure  \
# RowNumber         1.000000    0.004202     0.005840  0.000783 -0.006495
# CustomerId        0.004202    1.000000     0.005308  0.009497 -0.014883
# CreditScore       0.005840    0.005308     1.000000 -0.003965  0.000842
# Age               0.000783    0.009497    -0.003965  1.000000 -0.009997
# Tenure           -0.006495   -0.014883     0.000842 -0.009997  1.000000
# Balance          -0.009067   -0.012419     0.006268  0.028308 -0.012254
# NumOfProducts     0.007246    0.016972     0.012238 -0.030680  0.013444
# HasCrCard         0.000599   -0.014025    -0.005458 -0.011721  0.022583
# ...

# %%
corr=dataset.corr()
sns.heatmap(corr)

# sns.heatmap(corr,annot=True) # to get numbers inside them
# Out:
# C:\Users\sikha\AppData\Local\Temp\ipykernel_13300\1582916767.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=dataset.corr()
# <Axes: >

# %%
plt.subplots(figsize=(20,15))
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # 3. handling null values

# %%
dataset.isnull().any()
# Out:
# RowNumber          False
# CustomerId         False
# Surname            False
# CreditScore        False
# Geography          False
# Gender             False
# Age                False
# Tenure             False
# Balance            False
# NumOfProducts      False
# HasCrCard          False
# IsActiveMember     False
# EstimatedSalary    False
# Exited             False
# dtype: bool

# %%
dataset.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [raw]
# there are no null values here, hence no null handling will be done.

# %% [raw]
# but let us assume some  null values in age column and gender column.

# %%
# handling null values in age
# numerical data

dataset["Age"].fillna(dataset["Age"].mean(),inplace=True)

# %%
# handling in gender

dataset["Gender"].fillna(dataset["Gender"].mode()[0],inplace=True)

# %% [markdown]
# # 4. Seperating dependent and independent variables

# %%
dataset.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
x=dataset.loc[:,"CreditScore":"EstimatedSalary"]

# %%
x
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# ...

# %%
x=dataset.iloc[:,3:13]
y=dataset.iloc[:,13:] 

# here x is selecting all independent variables
# and y is selcting the dependent variable

# %%
x.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1        101348.88
# 1          0               1        112542.58
# 2          1               0        113931.57
# 3          0               0         93826.63
# 4          1               1         79084.10

# %%
y.head()
# Out:
#    Exited
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0

# %%
x.shape,y.shape
# Out:
# ((10000, 10), (10000, 1))

# %% [markdown]
# # 5. Encoding dependent and independent ones

# %% [raw]
# Two types of encoding:
#     1. nominal encoding:
#         arrangement of data is not required
#
#         a. one hot encoding
#         b. one hot encoding with many categorical variables
#         c. mean encoding
#
#
#
#     2. ordinal encoding:
#         take care of rank of data
#
#         a. label encoding
#         b. target guided ordinal encoding

# %% [markdown]
# ## label encoding on Gender column

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
x["Gender"]=le.fit_transform(x["Gender"])

# %% [raw]
# since the gender has only two categories(types of values in columns), label encoding is performed

# %%
x["Gender"]
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 9995    1
# 9996    1
# 9997    0
# 9998    1
# 9999    0
# Name: Gender, Length: 10000, dtype: int32

# %%
x.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France       0   42       2       0.00              1
# 1          608     Spain       0   41       1   83807.86              1
# 2          502    France       0   42       8  159660.80              3
# 3          699    France       0   39       1       0.00              2
# 4          850     Spain       0   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1        101348.88
# 1          0               1        112542.58
# 2          1               0        113931.57
# 3          0               0         93826.63
# 4          1               1         79084.10

# %% [markdown]
# ## one hot encoding on geography column

# %% [raw]
# curse of dimensionality

# %%
x.shape
# Out:
# (10000, 10)

# %%
geography=pd.get_dummies(x["Geography"],drop_first=True)

# %%
geography
# Out:
#       Germany  Spain
# 0           0      0
# 1           0      1
# 2           0      0
# 3           0      0
# 4           0      1
# ...       ...    ...
# 9995        0      0
# 9996        0      0
# 9997        0      0
# 9998        1      0
# 9999        0      0
#
# [10000 rows x 2 columns]

# %%
x=pd.concat([x,geography],axis=1)

# %%
x.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France       0   42       2       0.00              1
# 1          608     Spain       0   41       1   83807.86              1
# 2          502    France       0   42       8  159660.80              3
# 3          699    France       0   39       1       0.00              2
# 4          850     Spain       0   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Germany  Spain
# 0          1               1        101348.88        0      0
# 1          0               1        112542.58        0      1
# 2          1               0        113931.57        0      0
# 3          0               0         93826.63        0      0
# 4          1               1         79084.10        0      1

# %%
#drop geography column
x.drop(["Geography"],axis=1,inplace=True)

# %%
x.head()
# Out:
#    CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619       0   42       2       0.00              1          1
# 1          608       0   41       1   83807.86              1          0
# 2          502       0   42       8  159660.80              3          1
# 3          699       0   39       1       0.00              2          0
# 4          850       0   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Germany  Spain
# 0               1        101348.88        0      0
# 1               1        112542.58        0      1
# 2               0        113931.57        0      0
# 3               0         93826.63        0      0
# 4               1         79084.10        0      1

# %%
x.shape
# Out:
# (10000, 11)

# %% [markdown]
# ## splitting into training and testing set

# %% [raw]
# we need to split the data into 2 or 3 parts
#     1. training set 70-80 %
#     2. testing set  20-30 %
#     3. validatioin set (optional)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((7000, 11), (3000, 11), (7000, 1), (3000, 1))

# %%
a=[1,2,3,4,5,6]
b=[1,0,1,5,6,3]

for i in range(5):
    a_train,a_test,b_train,b_test=train_test_split(a,b,test_size=0.3)
    print("with random state",a_train)
    print("test part",a_test)
# Out:
# with random state [3, 5, 2, 4]
# test part [6, 1]
# with random state [2, 6, 1, 3]
# test part [4, 5]
# with random state [1, 4, 2, 3]
# test part [5, 6]
# with random state [2, 3, 5, 4]
# test part [1, 6]
# with random state [5, 1, 6, 4]
# test part [2, 3]

# %% [raw]
# in this way, we can test with the same data, but in a random manner
#
# but this may result in different answers in different senarios

# %% [markdown]
# ## Feature Scaling

# %% [raw]
# height cms
# weight kgs
#
# Standard Scaling
#     Data is manipulated to make mean=0 sd=1
#
# min max Scaling
#     range from 0 to 1

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
x_train=sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)

# %%
x_train
# Out:
# array([[-0.09792126,  0.92295821, -0.55759842, ..., -0.76862426,
#         -0.56987189, -0.5731713 ],
#        [-1.12612023,  0.92295821,  0.01725942, ..., -1.39359887,
#         -0.56987189, -0.5731713 ],
#        [-0.62230274, -1.08347268,  3.5622161 , ..., -1.49739308,
#         -0.56987189, -0.5731713 ],
#        ...,
#        [ 0.89943174,  0.92295821, -0.36597914, ...,  1.41400417,
#         -0.56987189, -0.5731713 ],
#        [-0.62230274, -1.08347268, -0.07855022, ...,  0.84625811,
#         -0.56987189,  1.74467913],
#        [-0.28299708, -1.08347268,  0.87954618, ...,  0.32689267,
#          1.75478035, -0.5731713 ]])
