# %%
import seaborn as sns

# %%
df=sns.load_dataset("tips")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(x="total_bill",y="tip",data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# inference
#
# from the plot we can say that as the bill amount increses, the tip is also incresing,
#
# which means they are directly proportional.

# %%
sns.scatterplot(x="size",y="total_bill",data=df)
# Out:
# <Axes: xlabel='size', ylabel='total_bill'>

# %%
sns.scatterplot(x="size",y="tip",data=df)
# Out:
# <Axes: xlabel='size', ylabel='tip'>

# %% [markdown]
# largest tip is given at the presence of 3 people

# %%
sns.lineplot(x="size",y="total_bill",data=df,ci=None)

# ci means confidence interval
# if that is not given, then u will see a seperate interval also
# Out:
# <ipython-input-14-22152bea325a>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x="size",y="total_bill",data=df,ci=None)
# <Axes: xlabel='size', ylabel='total_bill'>

# %%
sns.distplot(df["tip"])
# Out:
# <ipython-input-15-eb92b9dfa26f>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["tip"])
# <Axes: xlabel='tip', ylabel='Density'>

# %% [markdown]
# inference:
#
# the tips are mostly ranged between 2 and 4

# %%
sns.relplot(x="total_bill",y="tip",data=df,hue="day") # rel plot is meant for relational plot

# %%
df["day"].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
sns.barplot(x="day",y="tip",data=df)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# inference:
#
# you can see the highest tips are on sundays

# %%
sns.barplot(x="sex",y="tip",data=df,ci=None)
# Out:
# <ipython-input-25-6e28bb1f6ece>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="sex",y="tip",data=df,ci=None)
# <Axes: xlabel='sex', ylabel='tip'>

# %% [markdown]
# inference:
#
# males give more tips than females

# %%
sns.barplot(data=df,x="sex",y="tip",hue="day")
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.countplot(x="sex",data=df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.jointplot(x="total_bill",y="tip",data=df)

# %%
sns.boxplot(x="day",y='total_bill',data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.scatterplot(x="day",y='total_bill',data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# age
#
# 1 2 7 9 2 34 37 200
#
# 1 2 2 7 9 34 37 200
#
# Q1=2 =LOWER QUARTILE
#
# Median ==9+7/2=8 Q2
#
# Q3=35.5=UPEER QUARTILLE
#
# IQR=INTER QUARTILE RANGE=Q3-Q1

# %% [markdown]
# # Correlation

# %% [markdown]
# positive correlation:
#
# negative correlation:
#
# neutral correlation:

# %%
df.corr()
# Out:
# <ipython-input-33-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %% [markdown]
# > 0.5 means high corelation
#
# < 0.5 is low corelation

# %% [markdown]
# # heat map

# %%
corr=df.corr()
sns.heatmap(corr,annot=True,cmap="YlGnBu") # annotation for the number in the boxes
# cmap means colour map
# Out:
# <ipython-input-41-4f4506da71d1>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=df.corr()
# <Axes: >
